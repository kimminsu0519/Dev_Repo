# %%
import mysql.connector
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /home/kms/dev_ws/sql/src/.venv/bin/python

# %%
mydb = mysql.connector.connect(
    host = "localhost",
    user = "root",
    password = "1234"
)

# %%
mydb.close()

# %%
mydb = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = ""
)

# %%
remote = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)
cur = remote.cursor()
cur.execute("CREATE TABLE sql_file (id int, filename varchar(16))")
remote.close()

# %%
remote = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)
cur = remote.cursor()
cur.execute("DROP TABLE sql_file")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 remote = mysql.connector.connect(
#       2     host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
#       3     port = 3306,
#       4     user = "root",
#       5     password = "ajferhcz135",
#       6     database = "amrbase"
#       7 )
#       8 cur = remote.cursor()
#       9 cur.execute("DROP TABLE sql_file")
#
# NameError: name 'mysql' is not defined

# %%
remote = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)

cur = remote.cursor()
sql = open("test03.sql").read()
cur.execute(sql)

# %%
mydb = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)

mycursor = mydb.cursor()

sql = open("test04.sql").read()
result = mycursor.execute(sql)

# %%
remote = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)
cur = remote.cursor()
sql = open("test04.sql").read()
# for result_iterator in cur.execute(sql):
#     if result_iterator.with_rows:
#         print(result_iterator.fetchall())
#     else:
#         print(result_iterator.statement)

print(cur.execute(sql))

remote.commit()
# Out:
# None
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# Cell In[32], line 18
#      10 # for result_iterator in cur.execute(sql):
#      11 #     if result_iterator.with_rows:
#      12 #         print(result_iterator.fetchall())
#      13 #     else:
#      14 #         print(result_iterator.statement)
#      16 print(cur.execute(sql))
# ---> 18 remote.commit()
#
# File ~/dev_ws/sql/src/.venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:609, in CMySQLConnection.commit(self)
#     607 if self._cmysql:
#     608     self.handle_unread_result()
# --> 609     self._cmysql.commit()
#
# MySQLInterfaceError: Commands out of sync; you can't run this command now

# %%
remote = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)
cur = remote.cursor()
sql = open("test04.sql").read()
cur.execute(sql)

while cur.nextset():
    if cur.with_rows:
        result = cur.fetchall()
        print(result)

remote.commit()
cur.close()
remote.close()

# %%
import pandas as pd

# %%
import sys
print(sys.executable)
# Out:
# /home/kms/venv/eda_venv/bin/python3

# %%
import pandas as pd

df = pd.read_csv("/home/kms/dev_ws/sql/data/SQL_data/police_station.csv")
df.head()
# Out:
#    서울특별시경찰청       서울시 종로구 사직로8길 31
# 0   서울중부경찰서        서울특별시 중구 수표로 27
# 1   서울종로경찰서       서울특별시 종로구 율곡로 46
# 2  서울남대문경찰서      서울특별시 중구 한강대로 410
# 3  서울서대문경찰서     서울특별시 서대문구 통일로 113
# 4   서울혜화경찰서  서울특별시 종로구 창경궁로 112-16

# %%
conn = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)

# %%
cursor = conn.cursor(buffered=True)

# %%
sql = "insert into police_station (name, address) values (%s, %s)"

# %%
for i, row in df.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    conn.commit()
# Out:
# ('서울중부경찰서', '서울특별시 중구 수표로 27')
# ('서울종로경찰서', '서울특별시 종로구 율곡로 46')
# ('서울남대문경찰서', '서울특별시 중구 한강대로 410')
# ('서울서대문경찰서', '서울특별시 서대문구 통일로 113')
# ('서울혜화경찰서', '서울특별시 종로구 창경궁로 112-16')
# ('서울용산경찰서', '서울특별시 용산구 원효로89길 24')
# ('서울성북경찰서', '서울특별시 성북구 보문로 170')
# ('서울동대문경찰서', '서울특별시 동대문구 약령시로 21길 29')
# ('서울마포경찰서', '서울특별시 마포구 마포대로 183')
# ('서울영등포경찰서', '서울특별시 영등포구 국회대로 608')
# ('서울성동경찰서', '서울특별시 성동구 왕십리광장로 9')
# ('서울동작경찰서', '서울특별시 동작구 노량진로 148')
# ('서울광진경찰서', '서울특별시 광진구 광나루로 447 광진소방서 임시청사 (능동)')
# ('서울서부경찰서', '서울특별시 은평구 은평로9길 15')
# ('서울강북경찰서', '서울특별시 강북구 오패산로 406')
# ('서울금천경찰서', '서울특별시 관악구 남부순환로 1435')
# ('서울중랑경찰서', '서울특별시 중랑구 중랑역로 137')
# ('서울강남경찰서', '서울특별시 강남구 테헤란로 114길 11')
# ('서울관악경찰서', '서울특별시 관악구 관악로5길 33')
# ('서울강서경찰서', '서울특별시 양천구 화곡로 73')
# ('서울강동경찰서', '서울특별시 강동구 성내로 33')
# ('서울종암경찰서', '서울특별시 성북구 종암로 135')
# ('서울구로경찰서', '서울특별시 구로구 가마산로 235')
# ('서울서초경찰서', '서울특별시 서초구 반포대로 179')
# ('서울양천경찰서', '서울특별시 양천구 목동동로 99')
# ('서울송파경찰서', '서울특별시 송파구 중대로 221')
# ('서울노원경찰서', '서울특별시 노원구 노원로 283')
# ...

# %%
cursor.execute("select * from police_station")

result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# ('서울중부경찰서', '서울특별시 중구 수표로 27')
# ('서울종로경찰서', '서울특별시 종로구 율곡로 46')
# ('서울남대문경찰서', '서울특별시 중구 한강대로 41')
# ('서울서대문경찰서', '서울특별시 서대문구 통일로 1')
# ('서울혜화경찰서', '서울특별시 종로구 창경궁로 1')
# ('서울용산경찰서', '서울특별시 용산구 원효로89길')
# ('서울성북경찰서', '서울특별시 성북구 보문로 17')
# ('서울동대문경찰서', '서울특별시 동대문구 약령시로 ')
# ('서울마포경찰서', '서울특별시 마포구 마포대로 1')
# ('서울영등포경찰서', '서울특별시 영등포구 국회대로 ')
# ('서울성동경찰서', '서울특별시 성동구 왕십리광장로')
# ('서울동작경찰서', '서울특별시 동작구 노량진로 1')
# ('서울광진경찰서', '서울특별시 광진구 광나루로 4')
# ('서울서부경찰서', '서울특별시 은평구 은평로9길 ')
# ('서울강북경찰서', '서울특별시 강북구 오패산로 4')
# ('서울금천경찰서', '서울특별시 관악구 남부순환로 ')
# ('서울중랑경찰서', '서울특별시 중랑구 중랑역로 1')
# ('서울강남경찰서', '서울특별시 강남구 테헤란로 1')
# ('서울관악경찰서', '서울특별시 관악구 관악로5길 ')
# ('서울강서경찰서', '서울특별시 양천구 화곡로 73')
# ('서울강동경찰서', '서울특별시 강동구 성내로 33')
# ('서울종암경찰서', '서울특별시 성북구 종암로 13')
# ('서울구로경찰서', '서울특별시 구로구 가마산로 2')
# ('서울서초경찰서', '서울특별시 서초구 반포대로 1')
# ('서울양천경찰서', '서울특별시 양천구 목동동로 9')
# ('서울송파경찰서', '서울특별시 송파구 중대로 22')
# ('서울노원경찰서', '서울특별시 노원구 노원로 28')
# ('서울방배경찰서', '서울특별시 서초구 방배천로 5')
# ('서울도봉경찰서', '서울특별시 도봉구 노해로 40')
# ...

# %%
df = pd.DataFrame(result)
df
# Out:
#            0                 1
# 0    서울중부경찰서   서울특별시 중구 수표로 27
# 1    서울종로경찰서  서울특별시 종로구 율곡로 46
# 2   서울남대문경찰서  서울특별시 중구 한강대로 41
# 3   서울서대문경찰서  서울특별시 서대문구 통일로 1
# 4    서울혜화경찰서  서울특별시 종로구 창경궁로 1
# 5    서울용산경찰서  서울특별시 용산구 원효로89길
# 6    서울성북경찰서  서울특별시 성북구 보문로 17
# 7   서울동대문경찰서  서울특별시 동대문구 약령시로
# 8    서울마포경찰서  서울특별시 마포구 마포대로 1
# 9   서울영등포경찰서  서울특별시 영등포구 국회대로
# 10   서울성동경찰서  서울특별시 성동구 왕십리광장로
# 11   서울동작경찰서  서울특별시 동작구 노량진로 1
# 12   서울광진경찰서  서울특별시 광진구 광나루로 4
# 13   서울서부경찰서  서울특별시 은평구 은평로9길
# 14   서울강북경찰서  서울특별시 강북구 오패산로 4
# 15   서울금천경찰서  서울특별시 관악구 남부순환로
# 16   서울중랑경찰서  서울특별시 중랑구 중랑역로 1
# 17   서울강남경찰서  서울특별시 강남구 테헤란로 1
# 18   서울관악경찰서  서울특별시 관악구 관악로5길
# 19   서울강서경찰서  서울특별시 양천구 화곡로 73
# 20   서울강동경찰서  서울특별시 강동구 성내로 33
# 21   서울종암경찰서  서울특별시 성북구 종암로 13
# 22   서울구로경찰서  서울특별시 구로구 가마산로 2
# 23   서울서초경찰서  서울특별시 서초구 반포대로 1
# 24   서울양천경찰서  서울특별시 양천구 목동동로 9
# 25   서울송파경찰서  서울특별시 송파구 중대로 22
# 26   서울노원경찰서  서울특별시 노원구 노원로 28
# 27   서울방배경찰서  서울특별시 서초구 방배천로 5
# 28   서울도봉경찰서  서울특별시 도봉구 노해로 40
# ...

# %%
import pandas as pd

df = pd.read_csv("/home/kms/dev_ws/sql/data/SQL_data/2020_crime.csv", encoding="euc-kr")
df.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    1
# 1  중부     살인   검거    1
# 2  중부     강도   발생    3
# 3  중부     강도   검거    4
# 4  중부  강간,추행   발생  113

# %%
import pandas as pd

df = pd.read_csv("/home/kms/dev_ws/sql/data/SQL_data/2020_crime.csv", encoding="euc-kr")
df.head()
# Out:
#    구분     죄종 발생검거   건수
# 0  중부     살인   발생    1
# 1  중부     살인   검거    1
# 2  중부     강도   발생    3
# 3  중부     강도   검거    4
# 4  중부  강간,추행   발생  113

# %%
conn = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)

# %%
sql = """INSERT INTO crime_status values ("2020", %s, %s, %s, %s)"""
cursor = conn.cursor(buffered=True)

# %%
for i, row in df.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    conn.commit()
# Out:
# ('중부', '살인', '발생', 1)
# ('중부', '살인', '검거', 1)
# ('중부', '강도', '발생', 3)
# ('중부', '강도', '검거', 4)
# ('중부', '강간,추행', '발생', 113)
# ('중부', '강간,추행', '검거', 76)
# ('중부', '절도', '발생', 943)
# ('중부', '절도', '검거', 495)
# ('중부', '폭력', '발생', 997)
# ('중부', '폭력', '검거', 830)
# ('종로', '살인', '발생', 9)
# ('종로', '살인', '검거', 6)
# ('종로', '강도', '발생', 4)
# ('종로', '강도', '검거', 4)
# ('종로', '강간,추행', '발생', 115)
# ('종로', '강간,추행', '검거', 93)
# ('종로', '절도', '발생', 602)
# ('종로', '절도', '검거', 284)
# ('종로', '폭력', '발생', 964)
# ('종로', '폭력', '검거', 792)
# ('남대문', '살인', '발생', 1)
# ('남대문', '살인', '검거', 1)
# ('남대문', '강도', '발생', 2)
# ('남대문', '강도', '검거', 2)
# ('남대문', '강간,추행', '발생', 73)
# ('남대문', '강간,추행', '검거', 52)
# ('남대문', '절도', '발생', 699)
# ('남대문', '절도', '검거', 368)
# ('남대문', '폭력', '발생', 579)
# ('남대문', '폭력', '검거', 494)
# ('서대문', '살인', '발생', 3)
# ('서대문', '살인', '검거', 3)
# ('서대문', '강도', '발생', 2)
# ('서대문', '강도', '검거', 1)
# ('서대문', '강간,추행', '발생', 159)
# ('서대문', '강간,추행', '검거', 149)
# ('서대문', '절도', '발생', 1077)
# ('서대문', '절도', '검거', 524)
# ...

# %%
cursor.execute("select * from crime_status")

result = cursor.fetchall()
for row in result:
    print(row)
# Out:
# (2020, '중부', '살인', '발생', 1)
# (2020, '중부', '살인', '검거', 1)
# (2020, '중부', '강도', '발생', 3)
# (2020, '중부', '강도', '검거', 4)
# (2020, '중부', '강간,추행', '발생', 113)
# (2020, '중부', '강간,추행', '검거', 76)
# (2020, '중부', '절도', '발생', 943)
# (2020, '중부', '절도', '검거', 495)
# (2020, '중부', '폭력', '발생', 997)
# (2020, '중부', '폭력', '검거', 830)
# (2020, '종로', '살인', '발생', 9)
# (2020, '종로', '살인', '검거', 6)
# (2020, '종로', '강도', '발생', 4)
# (2020, '종로', '강도', '검거', 4)
# (2020, '종로', '강간,추행', '발생', 115)
# (2020, '종로', '강간,추행', '검거', 93)
# (2020, '종로', '절도', '발생', 602)
# (2020, '종로', '절도', '검거', 284)
# (2020, '종로', '폭력', '발생', 964)
# (2020, '종로', '폭력', '검거', 792)
# (2020, '남대문', '살인', '발생', 1)
# (2020, '남대문', '살인', '검거', 1)
# (2020, '남대문', '강도', '발생', 2)
# (2020, '남대문', '강도', '검거', 2)
# (2020, '남대문', '강간,추행', '발생', 73)
# (2020, '남대문', '강간,추행', '검거', 52)
# (2020, '남대문', '절도', '발생', 699)
# (2020, '남대문', '절도', '검거', 368)
# (2020, '남대문', '폭력', '발생', 579)
# (2020, '남대문', '폭력', '검거', 494)
# (2020, '서대문', '살인', '발생', 3)
# ...

# %%
df = pd.DataFrame(result)
df.head()
# Out:
#       0   1      2   3    4
# 0  2020  중부     살인  발생    1
# 1  2020  중부     살인  검거    1
# 2  2020  중부     강도  발생    3
# 3  2020  중부     강도  검거    4
# 4  2020  중부  강간,추행  발생  113

# %%
import mysql.connector

conn = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)
cursor = conn.cursor()

create_table_query = """
CREATE TABLE cctv_table(
    기관명 VARCHAR(20),
    소계 INT,
    `2013년_이전` INT,
    `2014년` INT,
    `2015년` INT,
    `2016년` INT
);
"""

# 쿼리 실행
cursor.execute(create_table_query)

# 변경 사항 저장
conn.commit()

# 연결 종료
cursor.close()
# conn.close()
# Out:
# True

# %%
import pandas as pd

df = pd.read_csv("/home/kms/dev_ws/sql/data/SQL_data/Seoul_CCTV.csv", encoding="utf-8")
df.head()
# Out:
#    기관명    소계  2013년도 이전  2014년  2015년  2016년
# 0  강남구  3238       1292    430    584    932
# 1  강동구  1010        379     99    155    377
# 2  강북구   831        369    120    138    204
# 3  강서구   911        388    258    184     81
# 4  관악구  2109        846    260    390    613

# %%
sql = """INSERT INTO cctv_table values (%s, %s, %s, %s, %s, %s)"""
cursor = conn.cursor(buffered=True)

for i, row in df.iterrows():
    cursor.execute(sql, tuple(row))
    print(tuple(row))
    conn.commit()
# Out:
# ('강남구', 3238, 1292, 430, 584, 932)
# ('강동구', 1010, 379, 99, 155, 377)
# ('강북구', 831, 369, 120, 138, 204)
# ('강서구', 911, 388, 258, 184, 81)
# ('관악구', 2109, 846, 260, 390, 613)
# ('광진구', 878, 573, 78, 53, 174)
# ('구로구', 1884, 1142, 173, 246, 323)
# ('금천구', 1348, 674, 51, 269, 354)
# ('노원구', 1566, 542, 57, 451, 516)
# ('도봉구', 825, 238, 159, 42, 386)
# ('동대문구', 1870, 1070, 23, 198, 579)
# ('동작구', 1302, 544, 341, 103, 314)
# ('마포구', 980, 314, 118, 169, 379)
# ('서대문구', 1254, 844, 50, 68, 292)
# ('서초구', 2297, 1406, 157, 336, 398)
# ('성동구', 1327, 730, 91, 241, 265)
# ('성북구', 1651, 1009, 78, 360, 204)
# ('송파구', 1081, 529, 21, 68, 463)
# ('양천구', 2482, 1843, 142, 30, 467)
# ('영등포구', 1277, 495, 214, 195, 373)
# ('용산구', 2096, 1368, 218, 112, 398)
# ('은평구', 2108, 1138, 224, 278, 468)
# ('종로구', 1619, 464, 314, 211, 630)
# ('중구', 1023, 413, 190, 72, 348)
# ('중랑구', 916, 509, 121, 177, 109)

# %%
conn.close()

# %%
conn = mysql.connector.connect(
    host = "studydb.clocgy680wga.ap-northeast-2.rds.amazonaws.com",
    port = 3306,
    user = "root",
    password = "ajferhcz135",
    database = "amrbase"
)

# 데이터 조회
with conn.cursor() as cur:
    cur.execute("SELECT * FROM cctv_table")
    rows = cur.fetchall()
    for row in rows:
        print(row)

conn.close()
# Out:
# ('강남구', 3238, 1292, 430, 584, 932)
# ('강동구', 1010, 379, 99, 155, 377)
# ('강북구', 831, 369, 120, 138, 204)
# ('강서구', 911, 388, 258, 184, 81)
# ('관악구', 2109, 846, 260, 390, 613)
# ('광진구', 878, 573, 78, 53, 174)
# ('구로구', 1884, 1142, 173, 246, 323)
# ('금천구', 1348, 674, 51, 269, 354)
# ('노원구', 1566, 542, 57, 451, 516)
# ('도봉구', 825, 238, 159, 42, 386)
# ('동대문구', 1870, 1070, 23, 198, 579)
# ('동작구', 1302, 544, 341, 103, 314)
# ('마포구', 980, 314, 118, 169, 379)
# ('서대문구', 1254, 844, 50, 68, 292)
# ('서초구', 2297, 1406, 157, 336, 398)
# ('성동구', 1327, 730, 91, 241, 265)
# ('성북구', 1651, 1009, 78, 360, 204)
# ('송파구', 1081, 529, 21, 68, 463)
# ('양천구', 2482, 1843, 142, 30, 467)
# ('영등포구', 1277, 495, 214, 195, 373)
# ('용산구', 2096, 1368, 218, 112, 398)
# ('은평구', 2108, 1138, 224, 278, 468)
# ('종로구', 1619, 464, 314, 211, 630)
# ('중구', 1023, 413, 190, 72, 348)
# ('중랑구', 916, 509, 121, 177, 109)
