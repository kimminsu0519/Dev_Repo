# %%
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
from user_agent import generate_user_agent
import re
from tqdm import tqdm

# %%
url = "https://www.chicagomag.com/chicago-magazine/august-2024/chicagos-50-best-restaurants-ranked/"

req = Request(url=url, headers={'User-Agent':generate_user_agent()})
page = urlopen(req)
soup = BeautifulSoup(page, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     Chicago’s 50 Best Restaurants, Ranked – Chicago Magazine
#    </title>
#    <meta content="max-image-preview:large" name="robots"/>
#    <style>
#     img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#    </style>
#    <!-- Google Tag Manager for WordPress by gtm4wp.com -->
#    <script data-cfasync="false" data-pagespeed-no-defer="">
#     var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
#    </script>
#    <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
# ...

# %%
total_tmp = soup.find("div", class_="br50")
rank_tmp = total_tmp.find_all("h2")
len(rank_tmp)
# Out:
# 50

# %%
print(rank_tmp[0].get_text())
# Out:
# 1Monteverde

# %%
text_tmp = re.split("(\d+)", rank_tmp[0].get_text())
print(text_tmp)
# Out:
# ['', '1', 'Monteverde']

# %%
total_list = []

for item in total_tmp.find_all("h2"):
    text_tmp = re.split("(\d+)", item.get_text())
    details_tmp_list = []

    details_tmp_list.append(text_tmp[1])
    details_tmp_list.append(text_tmp[2])

    total_list.append(details_tmp_list)
total_list
# Out:
# [['1', 'Monteverde'],
#  ['2', 'Oriole'],
#  ['3', 'Galit'],
#  ['4', 'Avec'],
#  ['5', 'Kasama'],
#  ['6', 'Virtue'],
#  ['7', 'HaiSous Vietnamese Kitchen'],
#  ['8', 'Shaw’s Crab House'],
#  ['9', 'Dear Margaret'],
#  ['10', 'Boka'],
#  ['11', 'Kyoten/Kyoten Next Door'],
#  ['12', 'Hermosa Restaurant'],
#  ['13', 'Warlord'],
#  ['14', 'Elske'],
#  ['15', 'John’s Food & Wine'],
#  ['16', 'El Che Steakhouse & Bar'],
#  ['17', 'Ever'],
#  ['18', 'Obélix'],
#  ['19', 'Sepia'],
#  ['20', 'Lula Cafe'],
#  ['21', 'Bungalow by Middle Brow'],
#  ['22', 'Atelier'],
#  ['23', 'La Chaparrita Grocery'],
#  ['24', 'Perilla'],
#  ['25', 'Superkhana International'],
#  ['26', 'Birrieria Zaragoza'],
#  ['27', 'Lem’s Bar-B-Q'],
#  ['28', 'Indienne'],
#  ['29', 'Demera'],
#  ['30', 'The Loyalist'],
#  ['31', 'JT’s Genuine Sandwich Shop'],
#  ['32', 'The Duck Inn'],
#  ['33', 'Mitsuwa Marketplace Food Court'],
#  ['34', 'Lilac Tiger'],
#  ['35', 'Bavette’s Bar & Boeuf'],
# ...

# %%
prefix = "https://www.chicagomag.com"
total_tmp.find_all("a")[1]["href"]
text_tmp = prefix + total_tmp.find_all("a")[29]["href"]
text_tmp
# Out:
# 'https://www.chicagomag.comhttps://www.chicagomag.com/cbr/'

# %%
print(len(total_tmp.find_all("a")))
# Out:
# 57

# %%
link_list = []
prefix = "https://www.chicagomag.com"


for idx, item in enumerate(total_tmp.find_all("a")):
    if item["href"][-4:] == "#" or item["href"][-4:] == "cbr/":
        continue

    link_list.append(prefix + item["href"])

for i in range(50):
    total_list[i].append(link_list[i])

# %%
total_list
# Out:
# [['1',
#   'Monteverde',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/monteverde/'],
#  ['2',
#   'Oriole',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/oriole/'],
#  ['3',
#   'Galit',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/galit/'],
#  ['4',
#   'Avec',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/avec/'],
#  ['5',
#   'Kasama',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/kasama/'],
#  ['6',
#   'Virtue',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/virtue/'],
#  ['7',
#   'HaiSous Vietnamese Kitchen',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/haisous-vietnamese-kitchen/'],
#  ['8',
#   'Shaw’s Crab House',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/shaws-crab-house/'],
#  ['9',
# ...

# %%
url_tmp = "https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/monteverde/"

req_tmp = Request(url=url_tmp, headers={'User-Agent':generate_user_agent()})
page_tmp = urlopen(req_tmp)
soup_tmp = BeautifulSoup(page_tmp, "html.parser")

print(soup_tmp.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible">
#    <link href="https://gmpg.org/xfn/11" rel="profile"/>
#    <script src="https://cmp.osano.com/16A1AnRt2Fn8i1unj/f15ebf08-7008-40fe-9af3-db96dc3e8266/osano.js">
#    </script>
#    <title>
#     Monteverde – Chicago Magazine
#    </title>
#    <meta content="max-image-preview:large" name="robots"/>
#    <style>
#     img:is([sizes="auto" i], [sizes^="auto," i]) { contain-intrinsic-size: 3000px 1500px }
#    </style>
#    <!-- Google Tag Manager for WordPress by gtm4wp.com -->
#    <script data-cfasync="false" data-pagespeed-no-defer="">
#     var gtm4wp_datalayer_name = "dataLayer";
# 	var dataLayer = dataLayer || [];
#    </script>
#    <!-- End Google Tag Manager for WordPress by gtm4wp.com -->
#    <meta content="width=device-width, initial-scale=1" name="viewport"/>
#    <link href="//cdnjs.cloudflare.com" rel="dns-prefetch">
# ...

# %%
details_tmp = soup_tmp.find("div", class_="article-body")
print(details_tmp.prettify())
# Out:
# <div class="article-body">
#  <!-- before the_content -->
#  <!-- the_content -->
#  <p>
# ...

# %%
introduction_tmp = details_tmp.find("p")
print(introduction_tmp.string)
# Out:
# Monteverde gets all the big things and all the little things right. It’s buzzy but not braying, easy on the eyes but not design-y, always busy but never a madhouse. We love the way the servers are comfily dressed and totally knowledgeable, and we love the ways around the always-filled reservation book, like by going for lunch or via the first-come, first-serve bar at dinner. We love the way the bill comes as a pleasant surprise, always less than expected. More than anything we love chef-owner Sarah Grueneberg’s (pictured) distinctive cooking, which is Italian by way of her native Texas. Time and again we simultaneously recognize and thrill to her flavors, like trying comfort food for the first time. Her bucatini with ricotta whey cacio e pepe is such a marvel — so sharp and peppery it slaps, so creamy you scrape the plate. We want anything bathed in her tomato sauce, from her soppressata meatballs, to a fantastic new dish of singed, wok-seared spaghetti with ground shrimp Bolognese a
# ...

# %%
details_tmp2 = details_tmp.find("div", class_="br50-footer")
price_tmp = details_tmp2.find("span", class_="light")
len(price_tmp.get_text())

print("$" * (5 - len(price_tmp.get_text())))
# Out:
# $$$

# %%
text_tmp2 = details_tmp2.get_text()
text_tmp2
# Out:
# '\n\nPrice:\n$$$$$\nAddress: 1020 W. Madison St.\nWebsite: monteverdechicago.com\n\n'

# %%
print(details_tmp2.get_text())
# Out:
# Price:
# $$$$$
# Address: 1020 W. Madison St.
# Website: monteverdechicago.com

# %%
check_tmp1 = re.search("Address:", text_tmp2).start()
check_tmp2 = re.search("Website:", text_tmp2).start()

address_tmp = text_tmp2[check_tmp1 + 9 : check_tmp2 - 1]
website_tmp = text_tmp2[check_tmp2 + 9 : -2]

address_tmp, website_tmp
# Out:
# ('1020 W. Madison St.', 'monteverdechicago.com')

# %%
price_list = []
address_list = []
website_list = []
prefix = "https://www.chicagomag.com"

for item in tqdm(total_tmp.find_all("a")):
    if item["href"][-4:] == "#" or item["href"][-4:] == "cbr/":
        continue
    
    url_tmp = prefix + item["href"]
    req_tmp = Request(url=url_tmp, headers={'User-Agent':generate_user_agent()})
    page_tmp = urlopen(req_tmp)
    soup_tmp = BeautifulSoup(page_tmp, "html.parser")
    details_tmp = soup_tmp.find("div", class_="article-body")
    details_tmp2 = details_tmp.find("div", class_="br50-footer")

    price_tmp = details_tmp2.find("span", class_="light")
    if price_tmp == None:
        price_list.append("$$$$$")
    else:
        price_list.append("$" * (5 - len(price_tmp.get_text())))

    text_tmp2 = details_tmp2.get_text()
    check_tmp1 = re.search("Address:", text_tmp2).start()
    check_tmp2 = re.search("Website:", text_tmp2).start()
    address_list.append(text_tmp2[check_tmp1 + 9 : check_tmp2 - 1])
    website_list.append(details_tmp2.find("a")["href"])

for i in range(50):
    total_list[i].append(price_list[i])
    total_list[i].append(address_list[i])
    total_list[i].append(website_list[i])
# Out:
# 100%|██████████| 57/57 [00:53<00:00,  1.07it/s]

# %%
total_list
# Out:
# [['1',
#   'Monteverde',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/monteverde/',
#   '$$$',
#   '1020 W. Madison St.',
#   'https://monteverdechicago.com'],
#  ['2',
#   'Oriole',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/oriole/',
#   '$$$$$',
#   '661 W. Walnut St.',
#   'https://www.oriolechicago.com'],
#  ['3',
#   'Galit',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/galit/',
#   '$$$$',
#   '2429 N. Lincoln Ave.',
#   'https://www.galitrestaurant.com'],
#  ['4',
#   'Avec',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/avec/',
#   '$$$',
#   '615 W. Randolph St. | 141 W. Erie St.',
#   'https://www.avecrestaurant.com'],
#  ['5',
#   'Kasama',
#   'https://www.chicagomag.com/chicago-magazine/august-2024/50-best-restaurants/kasama/',
#   '$$$$$',
#   '1001 N. Winchester Ave.',
#   'https://www.kasamachicago.com'],
#  ['6',
# ...

# %%
df = pd.DataFrame(total_list, columns=["Rank", "Restaurant_Name", "Link_details", "Price", "Address", "Wepsite"])
df
# Out:
#    Rank                 Restaurant_Name  \
# 0     1                      Monteverde
# 1     2                          Oriole
# 2     3                           Galit
# 3     4                            Avec
# 4     5                          Kasama
# 5     6                          Virtue
# 6     7      HaiSous Vietnamese Kitchen
# 7     8               Shaw’s Crab House
# 8     9                   Dear Margaret
# 9    10                            Boka
# 10   11         Kyoten/Kyoten Next Door
# 11   12              Hermosa Restaurant
# 12   13                         Warlord
# 13   14                           Elske
# 14   15              John’s Food & Wine
# 15   16         El Che Steakhouse & Bar
# 16   17                            Ever
# 17   18                          Obélix
# 18   19                           Sepia
# 19   20                       Lula Cafe
# 20   21         Bungalow by Middle Brow
# 21   22                         Atelier
# ...

# %%
df.to_csv("Chicago_Best_Restaurants_final.csv", index=False, encoding="utf-8")

# %%
del df["Link_details"]
df
# Out:
#    Rank                 Restaurant_Name  Price  \
# 0     1                      Monteverde    $$$
# 1     2                          Oriole  $$$$$
# 2     3                           Galit   $$$$
# 3     4                            Avec    $$$
# 4     5                          Kasama  $$$$$
# 5     6                          Virtue    $$$
# 6     7      HaiSous Vietnamese Kitchen    $$$
# 7     8               Shaw’s Crab House    $$$
# 8     9                   Dear Margaret    $$$
# 9    10                            Boka  $$$$$
# 10   11         Kyoten/Kyoten Next Door  $$$$$
# 11   12              Hermosa Restaurant    $$$
# 12   13                         Warlord   $$$$
# 13   14                           Elske   $$$$
# 14   15              John’s Food & Wine    $$$
# 15   16         El Che Steakhouse & Bar   $$$$
# 16   17                            Ever  $$$$$
# 17   18                          Obélix   $$$$
# 18   19                           Sepia    $$$
# ...

# %%
df.to_csv("Chicago_Best_Restaurants_Result_final.csv", index=False, encoding="utf-8")

# %%
import googlemaps

gmaps_key = "AIzaSyDPTBsHX0AodGhifbQTI3KlCHwUHyQKUqE"
gmaps = googlemaps.Client(key=gmaps_key)

geocode = gmaps.geocode("1020 W. Madison St.")
geocode
# Out:
# [{'address_components': [{'long_name': '1020',
#     'short_name': '1020',
#     'types': ['street_number']},
#    {'long_name': 'West Madison Street',
#     'short_name': 'W Madison St',
#     'types': ['route']},
#    {'long_name': 'West Loop',
#     'short_name': 'West Loop',
#     'types': ['neighborhood', 'political']},
#    {'long_name': 'Chicago',
#     'short_name': 'Chicago',
#     'types': ['locality', 'political']},
#    {'long_name': 'Cook County',
#     'short_name': 'Cook County',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Illinois',
#     'short_name': 'IL',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'United States',
#     'short_name': 'US',
#     'types': ['country', 'political']},
#    {'long_name': '60607', 'short_name': '60607', 'types': ['postal_code']},
#    {'long_name': '2008',
#     'short_name': '2008',
#     'types': ['postal_code_suffix']}],
# ...

# %%
lat = geocode[0].get("geometry")["location"]["lat"]
lng = geocode[0].get("geometry")["location"]["lng"]

lat, lng
# Out:
# (41.8819188, -87.6529673)

# %%
import folium

df = pd.read_csv("../src/Chicago_Best_Restaurants_Result_final.csv", index_col=0)
df.tail(10)
# Out:
#                 Restaurant_Name  Price  \
# Rank
# 41                    Boeufhaus   $$$$
# 42       New Village Gastro Pub     $$
# 43                     Bayan Ko    $$$
# 44                 Noon-O-Kabab     $$
# 45                Spacca Napoli     $$
# 46             Shanghai Terrace  $$$$$
# 47    Daisy’s Po-Boy and Tavern     $$
# 48      Dolo Restaurant and Bar     $$
# 49                 Redhot Ranch      $
# 50           Immm Rice & Beyond      $
#
#                                                 Address  \
# Rank
# 41                                 1012 N. Western Ave.
# 42                                  3566 Milwaukee Ave.
# 43                                1810 W. Montrose Ave.
# 44              4701 N. Kedzie Ave. | 242 Green Bay Rd.
# 45                               1769 W. Sunnyside Ave.
# 46                                  108 E. Superior St.
# 47                                  5215 S. Harper Ave.
# 48                                  2222 S. Archer Ave.
# ...

# %%
lat_list = []
lng_list = []

for idx, row in tqdm(df.iterrows(), total=len(df.index)):
    if "|" in row["Address"]:
        lat_list.append(np.nan)
        lng_list.append(np.nan)
        continue

    geocode = gmaps.geocode(row["Address"])

    if len(geocode) == 0:
        lat_list.append(np.nan)
        lng_list.append(np.nan)
    else:
        lat = geocode[0].get("geometry")["location"]["lat"]
        lng = geocode[0].get("geometry")["location"]["lng"]
        
        lat_list.append(lat)
        lng_list.append(lng)

len(lat_list), len(lng_list)
# Out:
# 100%|██████████| 50/50 [00:06<00:00,  7.63it/s]
# (50, 50)

# %%
df["lat"] = lat_list
df["lng"] = lng_list

df.head()
# Out:
#      Restaurant_Name  Price                                Address  \
# Rank
# 1         Monteverde    $$$                    1020 W. Madison St.
# 2             Oriole  $$$$$                      661 W. Walnut St.
# 3              Galit   $$$$                   2429 N. Lincoln Ave.
# 4               Avec    $$$  615 W. Randolph St. | 141 W. Erie St.
# 5             Kasama  $$$$$                1001 N. Winchester Ave.
#
#                               Wepsite        lat        lng
# Rank
# 1       https://monteverdechicago.com  41.881919 -87.652967
# 2       https://www.oriolechicago.com  32.916211 -96.638322
# 3     https://www.galitrestaurant.com  41.926341 -87.649460
# 4      https://www.avecrestaurant.com        NaN        NaN
# 5       https://www.kasamachicago.com  41.899689 -87.675601

# %%
df
# Out:
#                      Restaurant_Name  Price  \
# Rank
# 1                         Monteverde    $$$
# 2                             Oriole  $$$$$
# 3                              Galit   $$$$
# 4                               Avec    $$$
# 5                             Kasama  $$$$$
# 6                             Virtue    $$$
# 7         HaiSous Vietnamese Kitchen    $$$
# 8                  Shaw’s Crab House    $$$
# 9                      Dear Margaret    $$$
# 10                              Boka  $$$$$
# 11           Kyoten/Kyoten Next Door  $$$$$
# 12                Hermosa Restaurant    $$$
# 13                           Warlord   $$$$
# 14                             Elske   $$$$
# 15                John’s Food & Wine    $$$
# 16           El Che Steakhouse & Bar   $$$$
# 17                              Ever  $$$$$
# 18                            Obélix   $$$$
# 19                             Sepia    $$$
# 20                         Lula Cafe    $$$
# ...

# %%
mapping = folium.Map(location=[lat_list[0], lng_list[0]], zoom_start=11)
mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for idx, row in df.iterrows():
    if pd.isna(row["lat"]) or pd.isna(row["lng"]):  # NaN 값이 있으면 건너뛰기
        continue
    else:
        folium.Marker([row["lat"], row["lng"]], popup=row["Restaurant_Name"]).add_to(mapping)

mapping
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
df.to_csv("Chicago_Best_Restaurants_Result_final.csv", index=False, encoding="utf-8")

# %%
df
# Out:
#                      Restaurant_Name  Price  \
# Rank
# 1                         Monteverde    $$$
# 2                             Oriole  $$$$$
# 3                              Galit   $$$$
# 4                               Avec    $$$
# 5                             Kasama  $$$$$
# 6                             Virtue    $$$
# 7         HaiSous Vietnamese Kitchen    $$$
# 8                  Shaw’s Crab House    $$$
# 9                      Dear Margaret    $$$
# 10                              Boka  $$$$$
# 11           Kyoten/Kyoten Next Door  $$$$$
# 12                Hermosa Restaurant    $$$
# 13                           Warlord   $$$$
# 14                             Elske   $$$$
# 15                John’s Food & Wine    $$$
# 16           El Che Steakhouse & Bar   $$$$
# 17                              Ever  $$$$$
# 18                            Obélix   $$$$
# 19                             Sepia    $$$
# 20                         Lula Cafe    $$$
# ...

# %%
# '$' 개수를 기준으로 오름차순정렬
df["Price_Level"] = df["Price"].str.count("\$")
df_sorted = df.sort_values(by="Price_Level", ascending=True).drop(columns=["Price_Level"])
df_sorted
# Out:
#                      Restaurant_Name  Price  \
# Rank
# 26                Birrieria Zaragoza      $
# 27                     Lem’s Bar-B-Q      $
# 31        JT’s Genuine Sandwich Shop      $
# 23             La Chaparrita Grocery      $
# 49                      Redhot Ranch      $
# 50                Immm Rice & Beyond      $
# 33    Mitsuwa Marketplace Food Court      $
# 21           Bungalow by Middle Brow     $$
# 48           Dolo Restaurant and Bar     $$
# 38                              Roux     $$
# 47         Daisy’s Po-Boy and Tavern     $$
# 45                     Spacca Napoli     $$
# 34                       Lilac Tiger     $$
# 29                            Demera     $$
# 42            New Village Gastro Pub     $$
# 44                      Noon-O-Kabab     $$
# 30                      The Loyalist    $$$
# 25          Superkhana International    $$$
# 32                      The Duck Inn    $$$
# 37                           Daisies    $$$
# ...

# %%
# '$' 개수를 기준으로 내림차순정렬
df["Price_Level"] = df["Price"].str.count("\$")
df_sorted = df.sort_values(by="Price_Level", ascending=False).drop(columns=["Price_Level"])
df_sorted
# Out:
#                      Restaurant_Name  Price  \
# Rank
# 2                             Oriole  $$$$$
# 5                             Kasama  $$$$$
# 17                              Ever  $$$$$
# 10                              Boka  $$$$$
# 11           Kyoten/Kyoten Next Door  $$$$$
# 46                  Shanghai Terrace  $$$$$
# 35             Bavette’s Bar & Boeuf  $$$$$
# 40                             Schwa  $$$$$
# 28                          Indienne  $$$$$
# 22                           Atelier  $$$$$
# 13                           Warlord   $$$$
# 24                           Perilla   $$$$
# 41                         Boeufhaus   $$$$
# 16           El Che Steakhouse & Bar   $$$$
# 3                              Galit   $$$$
# 14                             Elske   $$$$
# 18                            Obélix   $$$$
# 1                         Monteverde    $$$
# 15                John’s Food & Wine    $$$
# 12                Hermosa Restaurant    $$$
# ...

# %%
df_sorted.to_csv("Chicago_Best_Restaurants_Descending_.csv")

# %%
df_sorted
# Out:
#                      Restaurant_Name  Price  \
# Rank
# 2                             Oriole  $$$$$
# 5                             Kasama  $$$$$
# 17                              Ever  $$$$$
# 10                              Boka  $$$$$
# 11           Kyoten/Kyoten Next Door  $$$$$
# 46                  Shanghai Terrace  $$$$$
# 35             Bavette’s Bar & Boeuf  $$$$$
# 40                             Schwa  $$$$$
# 28                          Indienne  $$$$$
# 22                           Atelier  $$$$$
# 13                           Warlord   $$$$
# 24                           Perilla   $$$$
# 41                         Boeufhaus   $$$$
# 16           El Che Steakhouse & Bar   $$$$
# 3                              Galit   $$$$
# 14                             Elske   $$$$
# 18                            Obélix   $$$$
# 1                         Monteverde    $$$
# 15                John’s Food & Wine    $$$
# 12                Hermosa Restaurant    $$$
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_sorted["Price_Level"] = df_sorted["Price"].astype(str).str.count("\$")
df_sorted.reset_index(drop=False, inplace=True)

# Price_Level과 Rank 간의 관계를 시각화 (선 그래프)
plt.figure(figsize=(10, 6))
plt.plot(df_sorted["Price_Level"], df_sorted["Rank"], marker='o', linestyle='-', color='blue')

plt.xlabel("Price Level ($)")
plt.ylabel("Rank")
plt.title("Price vs Rank Visualization")
plt.gca().invert_yaxis()  # Rank가 낮을수록 높은 순위이므로 Y축 반전
plt.grid(True)

# 그래프 표시
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_sorted["Price_Level"], df_sorted["Rank"], marker='o', linestyle='-', color='blue')

plt.xlabel("Price Level ($)")
plt.ylabel("Rank")
plt.title("Price vs Rank Visualization")
plt.gca().invert_yaxis()  # Rank가 낮을수록 높은 순위이므로 Y축 반전
plt.grid(True)

# 그래프 표시
plt.show()

# %%
# 산점도 그래프 
plt.figure(figsize=(10, 6))
plt.scatter(df_sorted["Price_Level"], df_sorted["Rank"], marker='o', color='blue')
plt.xlabel("Price Level ($)")
plt.ylabel("Rank")
plt.title("Price vs Rank Scatter Plot")
plt.gca().invert_yaxis()  # Rank가 낮을수록 높은 순위이므로 Y축 반전
plt.grid(True)

# 그래프 표시
plt.show()
