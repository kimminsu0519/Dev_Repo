# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
img = cv2.imread("../data/dog.jpeg")
type(img)
# Out:
# numpy.ndarray

# %%
img = cv2.imread("../data/dog_x.jpeg")
type(img)
# Out:
# [ WARN:0@4049.331] global loadsave.cpp:268 findDecoder imread_('../data/dog_x.jpeg'): can't open/read file: check file path/integrity
# NoneType

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(fix_img)

# %%
img_gray = cv2.imread("../data/dog.jpeg", cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray, cmap="gray")

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
new_img = cv2.resize(fix_img, (200, 120))
plt.imshow(new_img)

# %%
plt.imshow(cv2.flip(fix_img, 0))

# %%
plt.imshow(cv2.flip(fix_img, 1))

# %%
plt.imshow(cv2.flip(fix_img, -1))

# %%
plt.imshow(img_gray, cmap="gray")

# %%
cv2.imwrite("../data/dog_gray.jpg", img_gray)
# Out:
# True
